# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('D:/Smartphone-Price-Prediction-Project/Smartphone-Price-Prediction-Project/data/processed/cleaned_smartphones.csv')

# %%
df.head()
# Out:
#    rating                   Model    Price  Sim  5G  IrBlaster  NFC  Speed  \
# 0    89.0              oneplus 11  54999.0  1.0   1          0    1    3.2
# 1    81.0  oneplus nord ce 2 lite  19989.0  1.0   1          0    0    2.2
# 2    75.0      samsung galaxy a14  16499.0  1.0   1          0    0    2.4
# 3    81.0       motorola moto g62  14999.0  1.0   1          0    0    2.2
# 4    82.0      realme 10 pro plus  24999.0  1.0   1          0    0    2.6
#
#    Core ProcessorName  ...     Hz           Notches  RearCamera  RearMP  \
# 0   8.0    snapdragon  ...  120.0        punch hole         1.0    50.0
# 1   8.0    snapdragon  ...  120.0        punch hole         1.0    64.0
# 2   8.0        exynos  ...   90.0  water drop notch         1.0    50.0
# 3   8.0    snapdragon  ...  120.0        punch hole         1.0    50.0
# 4   8.0     dimensity  ...  120.0        punch hole         1.0   108.0
#
#    FrontMP  RearCameraCount  HasMemoryCard  IsHybrid  ExtraSupport       OS
# 0     16.0              3.0            0.0       0.0           0.0  android
# 1     16.0              3.0            1.0       1.0        1024.0  android
# 2     13.0              3.0            1.0       0.0        1024.0  android
# 3     16.0              3.0            1.0       1.0        1024.0  android
# 4     16.0              3.0            0.0       0.0           0.0  android
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 28 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   rating           879 non-null    float64
#  1   Model            1020 non-null   object
#  2   Price            1020 non-null   float64
#  3   Sim              1019 non-null   float64
#  4   5G               1020 non-null   int64
#  5   IrBlaster        1020 non-null   int64
#  6   NFC              1020 non-null   int64
#  7   Speed            945 non-null    float64
#  8   Core             980 non-null    float64
#  9   ProcessorName    967 non-null    object
#  10  Ram              993 non-null    float64
#  11  Rom              997 non-null    float64
#  12  Capacity         987 non-null    float64
#  13  Watt             769 non-null    float64
#  14  FastCharging     1020 non-null   int64
#  15  Inches           987 non-null    float64
#  16  Xaxis            987 non-null    float64
#  17  Yaxis            987 non-null    float64
#  18  Hz               611 non-null    float64
#  19  Notches          885 non-null    object
#  20  RearCamera       958 non-null    float64
#  21  RearMP           958 non-null    float64
#  22  FrontMP          958 non-null    float64
#  23  RearCameraCount  981 non-null    float64
#  24  HasMemoryCard    741 non-null    float64
#  25  IsHybrid         741 non-null    float64
#  26  ExtraSupport     622 non-null    float64
#  27  OS               743 non-null    object
# dtypes: float64(20), int64(4), object(4)
# memory usage: 223.3+ KB

# %%
df.describe()
# Out:
#            rating          Price          Sim           5G    IrBlaster  \
# count  879.000000    1020.000000  1019.000000  1020.000000  1020.000000
# mean    78.258248   31371.767647     0.979392     0.538235     0.155882
# std      7.402854   39168.942590     0.142139     0.498780     0.362922
# min     60.000000      99.000000     0.000000     0.000000     0.000000
# 25%     74.000000   12464.250000     1.000000     0.000000     0.000000
# 50%     80.000000   19815.000000     1.000000     1.000000     0.000000
# 75%     84.000000   34999.000000     1.000000     1.000000     0.000000
# max     89.000000  650000.000000     1.000000     1.000000     1.000000
#
#                NFC       Speed        Core         Ram          Rom  ...  \
# count  1020.000000  945.000000  980.000000  993.000000   997.000000  ...
# mean      0.385294    2.417280    7.741837    6.461181   138.653033  ...
# std       0.486903    0.476551    0.923910    2.828453   107.749089  ...
# min       0.000000    1.000000    1.000000    0.003900     0.003900  ...
# 25%       0.000000    2.050000    8.000000    4.000000    64.000000  ...
# 50%       0.000000    2.300000    8.000000    6.000000   128.000000  ...
# 75%       1.000000    2.840000    8.000000    8.000000   128.000000  ...
# max       1.000000    3.220000    8.000000   18.000000  1024.000000  ...
#
#              Xaxis        Yaxis          Hz  RearCamera      RearMP  \
# count   987.000000   987.000000  611.000000  958.000000  958.000000
# mean   1060.914894  2179.227964  111.638298    0.995825   49.973904
# std     309.291602   572.898548   18.530837    0.064516   33.549655
# min     120.000000   160.000000   90.000000    0.000000    0.000000
# 25%    1080.000000  1612.000000   90.000000    1.000000   16.000000
# 50%    1080.000000  2400.000000  120.000000    1.000000   50.000000
# 75%    1080.000000  2408.000000  120.000000    1.000000   64.000000
# max    2460.000000  3840.000000  240.000000    1.000000  200.000000
#
#           FrontMP  RearCameraCount  HasMemoryCard    IsHybrid  ExtraSupport
# count  958.000000       981.000000     741.000000  741.000000    622.000000
# mean    16.290397         2.769623       0.848853    0.205128    592.424437
# std     11.056087         0.813116       0.358434    0.404068    439.126669
# min      0.000000         0.000000       0.000000    0.000000      0.000000
# 25%      8.000000         2.000000       1.000000    0.000000    256.000000
# 50%     16.000000         3.000000       1.000000    0.000000    512.000000
# 75%     16.000000         3.000000       1.000000    0.000000   1024.000000
# max     60.000000         4.000000       1.000000    1.000000   2048.000000
#
# [8 rows x 24 columns]

# %%
df.isna().sum()
# Out:
# rating             141
# Model                0
# Price                0
# Sim                  1
# 5G                   0
# IrBlaster            0
# NFC                  0
# Speed               75
# Core                40
# ProcessorName       53
# Ram                 27
# Rom                 23
# Capacity            33
# Watt               251
# FastCharging         0
# Inches              33
# Xaxis               33
# Yaxis               33
# Hz                 409
# Notches            135
# RearCamera          62
# RearMP              62
# FrontMP             62
# RearCameraCount     39
# HasMemoryCard      279
# IsHybrid           279
# ExtraSupport       398
# OS                 277
# dtype: int64

# %%
sns.histplot(data = df, x = "rating", kde=True, bins=25, color="teal", edgecolor="black")

plt.title("Distribution of Smartphone Ratings")
plt.xlabel("Rating (Score out of 100)")
plt.ylabel("Number of Smartphones")
plt.tight_layout()
plt.show()

# %%
sns.histplot(data=df, x = 'Price', kde=True, bins=35, color="royalblue")

plt.title("Distribution of Price (Right-Skewed)")
plt.xlabel("Price")
plt.ylabel("Count")
plt.show()

# %%
# Top 15 smartphone model counts
top_15_brands = df["Model"].value_counts().head(15)

sns.barplot(x=top_15_brands.values, y=top_15_brands.index, palette="Blues_r")
plt.title("Top 15 Smartphone Brands by Model Count")
plt.xlabel("Number of Models")
plt.ylabel("Brand")
plt.show()
# Out:
# C:\Users\sachi\AppData\Local\Temp\ipykernel_15516\1546101787.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_15_brands.values, y=top_15_brands.index, palette="Blues_r")

# %%
top_7_brands = df["Model"].value_counts().head(7).index
brand_subset = df[df["Model"].isin(top_7_brands)]

plt.figure(figsize=(9, 5))
sns.boxplot(data=brand_subset, x="Model", y="Price", palette="Set3")
plt.yscale("log")
plt.title("Log-Scaled Price Distribution Across Top 7 Brands")
plt.xlabel("Brand")
plt.xticks(rotation=10)
plt.ylabel("Price (Log Scale)")
plt.show()
# Out:
# C:\Users\sachi\AppData\Local\Temp\ipykernel_15516\115043703.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=brand_subset, x="Model", y="Price", palette="Set3")

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x="Ram", y="Price", hue="5G")
plt.yscale("log")
plt.title("Price vs RAM Capacity (Colored by 5G Support)")
plt.xlabel("RAM (GB)")
plt.ylabel("Price (Log Scale)")
plt.show()

# %%
# Price vs NFC with bar plot.
sns.countplot(data=df, x = "Sim", hue='NFC')
# Out:
# <Axes: xlabel='Sim', ylabel='count'>

# %%
sns.countplot(data=df[df["Ram"] >= 1], x="Ram",hue="Ram", palette="Blues")
# Out:
# <Axes: xlabel='Ram', ylabel='count'>

# %%
sns.boxplot(data=df[df["Ram"] >= 1], x="Ram", y="Price",hue="Ram", palette="Blues")
# Out:
# <Axes: xlabel='Ram', ylabel='Price'>

# %%
sns.countplot(data=df[df["Rom"] >= 16], x="Rom",hue="Rom", palette="Purples_r")
# Out:
# <Axes: xlabel='Rom', ylabel='count'>

# %%
sns.boxplot(data=df[df["Rom"] >= 32], x="Rom", y="Price",hue="Rom", palette="Purples")
# Out:
# <Axes: xlabel='Rom', ylabel='Price'>

# %%
sns.histplot(df["Capacity"].dropna(), bins=25, kde=True, color="green")
# Out:
# <Axes: xlabel='Capacity', ylabel='Count'>

# %%
sns.histplot(df["Watt"].dropna(), bins=20, kde=True, color="goldenrod")
# Out:
# <Axes: xlabel='Watt', ylabel='Count'>

# %%
sns.countplot(data=df, x="FastCharging",hue="FastCharging", palette="pastel")
# Out:
# <Axes: xlabel='FastCharging', ylabel='count'>

# %%
sns.countplot(data=df.dropna(subset=["Hz"]), x="Hz",hue="Hz", palette="viridis")
# Out:
# <Axes: xlabel='Hz', ylabel='count'>

# %%
sns.histplot(df["Inches"].dropna(), kde=True, bins=20)
# Out:
# <Axes: xlabel='Inches', ylabel='Count'>
