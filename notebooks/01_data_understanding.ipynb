# %% [markdown]
# ## Import Libraries for intial Data Understanding

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv('D:/Smartphone-Price-Prediction-Project/Smartphone-Price-Prediction-Project/data/raw/smartphones - smartphones.csv')

# %%
df.head()
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
# 3       Motorola Moto G62 5G  ₹14,999    81.0
# 4         Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# ...

# %%
df.shape
# Out:
# (1020, 11)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   str
#  1   price      1020 non-null   str
#  2   rating     879 non-null    float64
#  3   sim        1020 non-null   str
#  4   processor  1020 non-null   str
#  5   ram        1020 non-null   str
#  6   battery    1020 non-null   str
#  7   display    1020 non-null   str
#  8   camera     1019 non-null   str
#  9   card       1013 non-null   str
#  10  os         1003 non-null   str
# dtypes: float64(1), str(10)
# memory usage: 408.8 KB

# %%
df.describe()
# Out:
#            rating
# count  879.000000
# mean    78.258248
# std      7.402854
# min     60.000000
# 25%     74.000000
# 50%     80.000000
# 75%     84.000000
# max     89.000000

# %%
df.isnull().sum()
# Out:
# model          0
# price          0
# rating       141
# sim            0
# processor      0
# ram            0
# battery        0
# display        0
# camera         1
# card           7
# os            17
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['price'].describe()
# Out:
# count        1020
# unique        412
# top       ₹14,999
# freq           21
# Name: price, dtype: object

# %%
df['model'].describe()
# Out:
# count              1020
# unique             1020
# top       OnePlus 11 5G
# freq                  1
# Name: model, dtype: object

# %%
df.columns
# Out:
# Index(['model', 'price', 'rating', 'sim', 'processor', 'ram', 'battery',
#        'display', 'camera', 'card', 'os'],
#       dtype='str')

# %%
df.describe(include='object')
# Out:
# C:\Users\sachi\AppData\Local\Temp\ipykernel_20376\87514550.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include='object')
#                 model    price                             sim  \
# count            1020     1020                            1020
# unique           1020      412                              28
# top     OnePlus 11 5G  ₹14,999  Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# freq                1       21                             324
#
#                                              processor  \
# ...

# %%
df['os'].value_counts()
# Out:
# os
# Android v12                           287
# Android v11                           233
# No FM Radio                           192
# Android v10                            58
# Android v13                            45
# Bluetooth                              38
# Android v9.0 (Pie)                     27
# Android v10.0                          22
# iOS v16                                14
# iOS v15                                10
# Android v8.1 (Oreo)                    10
# Memory Card Not Supported               6
# Android v11.0                           4
# Android v8.0 (Oreo)                     4
# Browser                                 4
# iOS v13                                 3
# iOS v15.0                               3
# Memory Card Supported, upto 32 GB       3
# Android v6.0 (Marshmallow)              3
# Memory Card Supported, upto 256 GB      2
# Android v5.1.1 (Lollipop)               2
# Memory Card Supported, upto 64 GB       2
# ...

# %%
df['ram'].unique()
# Out:
# <ArrowStringArray>
# [       '12 GB RAM, 256 GB inbuilt',         '6 GB RAM, 128 GB inbuilt',
#           '4 GB RAM, 64 GB inbuilt',         '8 GB RAM, 256 GB inbuilt',
#          '8 GB RAM, 128 GB inbuilt',         '4 GB RAM, 128 GB inbuilt',
#           '3 GB RAM, 32 GB inbuilt',        '16 GB RAM, 256 GB inbuilt',
#           '6 GB RAM, 64 GB inbuilt',          '4 GB RAM, 32 GB inbuilt',
#           '3 GB RAM, 64 GB inbuilt',          '2 GB RAM, 32 GB inbuilt',
#         '16 GB RAM, 512 GB inbuilt',          '2 GB RAM, 64 GB inbuilt',
#          '4 GB RAM, 512 MB inbuilt',         '6 GB RAM, 256 GB inbuilt',
#         '12 GB RAM, 128 GB inbuilt',         '512 MB RAM, 4 GB inbuilt',
#         '18 GB RAM, 512 GB inbuilt',           '6 GB RAM, 1 TB inbuilt',
#         '12 GB RAM, 512 GB inbuilt',         '4 GB RAM, 256 GB inbuilt',
#                       'Unisoc T107',          '1 GB RAM, 16 GB inbuilt',
#         '18 GB RAM, 256 GB inbuilt',                    '64 GB inbuilt',
# ...
